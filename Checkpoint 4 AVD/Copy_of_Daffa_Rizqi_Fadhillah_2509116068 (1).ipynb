# %% [markdown]
# #**Analisis Pengaruh Diskon Terhadap Penjualan Produk Berdasarkan Rating pada Dataset Amazon Sales**

# %% [markdown]
# #**Import Library**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #**Memuat Dataset**

# %%
import pandas as pd

file = "/amazon.csv"
df = pd.read_csv(file)
df
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             ₹399
# ...

# %% [markdown]
# #**Business Understanding**

# %% [markdown]
# ##**Business Objective**

# %% [markdown]
# Tujuan dari analisis ini adalah memahami bagaimana diskon mempengaruhi performa rating yang diberikan dari konsumen terhadap penjualan suatu produk pada platform Amazon. Dengan adanya analisis ini, diharapkan para produsen dapat membaca minat para konsumen terhadap diskon yang diberikan, yang dimana apakah diskon yang diberikan efektif dalam meningkatkan daya tarik konsumen atau bahkan sebaliknya, sehingga dapat menjadi dasar strategi dalam pemasaran produk.

# %% [markdown]
# ## Assess Situation

# %% [markdown]
# Dalam dunia e-commerce, diskon merupakan hal yang cukup menarik bagi para konsumen, diskon juga sering menjadi salah satu strategi yang cukup efektif yang digunakan para produsen untuk menarik peminat. Namun, tidak semua diskon memberikan dampak yang setara terhadap penjualan. Oleh karena itu, penjual perlu menganalisa data untuk memahami hubungan antara diskon dan performa produk. Dalam dataset Amazon Sales ini, menyediakan informasi terkait harga asli, harga diskon, dan rating yang dapat digunakan untuk mengevaluasi efektivitas strategi diskon pada produk.

# %% [markdown]
# ##**Analytic Goals & Project Plan**

# %% [markdown]
# ###**Analytic Goals**

# %% [markdown]
# **Analytic Goals**
#
# Tujuan analisa dalam project ini adalah:
#
#
#
# *   Mengidentifikasi hubungan antara persentase diskon dan rating produk untuk melihat apakah diskon berpengaruh terhadap penilaian konsumen.
# *   Menganalisis popularitas dan tren produk berdasarkan rating sebagai indikator minat konsumen terhadap produk yang memiliki diskon.
#
# *   Membandingkan kategori produk untuk mengetahui kategori mana yang lebih sering mwnawarkan diskon dan memiliki performa rating yang baik.
# *   Mengidentifikasi pola strategi penjualan suatu produk berdasarkan pola dasar seperti harga asli, harga diskon, dan rating dari para konsumen.
#
# **Project Plan**
#
# Rencana analisis project ini adalah:
#
#
# *   Memuat dataset Amazon untuk memahami kolom yang berkaitan dengan harga asli, harga diskon, persentase diskon dan rating produk.
# *   Menyiapkan data diskon dengan memastikan format harga dan persentase yang dapat dianalisa dengan benar.
# *   Menganalisis hubungan antara persentase diskon dengan rating produk untuk melihat perbandingan kualitas produk yang diberi diskon.
# *   Mengamati popularitas produk berdasarkan rating pada produk dengan berbagai tingkat diskon.
# *   Membandingkan kategori produk untuk melihat pola diskon dan performa rating produk.
# *   Menjadikan salah satu strategi pemberian diskon yang efektif untuk menarik konsumen berdasarkan hasil analis.

# %% [markdown]
# #**Data Understanding**

# %% [markdown]
# ##**Struktur Data**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   object
#  4   actual_price         1465 non-null   object
#  5   discount_percentage  1465 non-null   object
#  6   rating               1465 non-null   object
#  7   rating_count         1463 non-null   object
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
# ...

# %% [markdown]
# Berdasarkan hasil dari informasi lanjutan, dataset Amazon memiliki 1465 baris dan 16 kolom. Hampir seluruh kolom memiliki non-null atau kolom yang terisi yang berarti tidak ada missing value, namun terdapat 1463 non-null pada kolom rating_count, sehingga terdapat 2 missing value pada kolom tersebut. Selain itu juga bagian Dtype pada kolom discounted_price, actual_price, discount_percentage, rating, dan rating_count merupakan "object" yang dimana seharusnya tipe data tersebut adalah Integer, tetapi terdapat kesalahan pada penulisan dataset yang dimana pada kolom tersebut menggunakan simbol seperti simbol mata uang Indian Rupee dan simbol diskon. Terdapat juga kesalahan penginputan pada kolom rating yang seharusnya Float namun menjadi Object.

# %% [markdown]
# ##**Statistik Deskriptif**

# %%
df.describe()
# Out:
#         product_id                                       product_name  \
# count         1465                                               1465
# unique        1351                                               1337
# top     B083342NKJ  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# freq             3                                                  5
#
#                                                  category discounted_price  \
# count                                                1465             1465
# unique                                                211              550
# top     Computers&Accessories|Accessories&Peripherals|...             ₹199
# freq                                                  233               53
#
#        actual_price discount_percentage rating rating_count  \
# count          1465                1465   1465         1463
# unique          449                  92     28         1143
# ...

# %% [markdown]
# Hasil dari deskriptif data diatas menunjukkan bahwa dataset memiliki 1465 data produk dengan tingkat kelengkapan data yang baik. Kolom category memiliki 211 kategori unik, yang mana menunjukkan variasi produk yang sangat beragam. Kolom harga memiliki ratusan nilai unik yang berarti adanya variasi harga dalam dataset. Harga diskon yang paling sering muncul adalah ₹199, sedangkan harga asli yang sering muncul adalah ₹999. Selain itu, diskon 50% merupakan nilai diskon yang dominan.

# %% [markdown]
# ##**Tipe Data Setiap Kolom**

# %%
df.dtypes
# Out:
# product_id             object
# product_name           object
# category               object
# discounted_price       object
# actual_price           object
# discount_percentage    object
# rating                 object
# rating_count           object
# about_product          object
# user_id                object
# user_name              object
# review_id              object
# review_title           object
# review_content         object
# img_link               object
# product_link           object
# dtype: object

# %% [markdown]
# Berdasarkan hasil pengecekan tipe data, seluruh kolom menunjukkan dtypes bertipe object. Hal ini menunjukkan bahwa semua data masih terbaca sebagai teks, termasuk kolom  seperti iscounted_price, actual_price, discount_percentage, rating, dan rating_count. Hal ini terjadi dikarenakan pada kolom tersebut terdapat memiliki simbol tambahan seperti diskon dan mata uang Indian Rupee, sehingga data mengenali hal tersebut sebagai object.

# %% [markdown]
# #**Incosistent Values Pada Setiap Kolom**

# %%
df['product_id'].unique()
# Out:
# array(['B07JW9H4J1', 'B098NS6PVG', 'B096MSW6CT', ..., 'B009P2LIL4',
#        'B00J5DYCCA', 'B01486F4G6'], dtype=object)

# %% [markdown]
# Berdasarkan hasil pengecekan pada kolom product_id, terlihat bahwa semua produk memiliki kode uniknya tersendiri yang saling berbeda dan berbentuk kombinasi antara huruf serta angka. Kemudian tidak ditemukan adanya indikasi inkonsisten pada kolom product_id karena seluruh nilai memiliki kode uniknya tersendiri.

# %%
df['product_name'].unique()
# Out:
# array(['Wayona Nylon Braided USB to Lightning Fast Charging and Data Sync Cable Compatible for iPhone 13, 12,11, X, 8, 7, 6, 5, iPad Air, Pro, Mini (3 FT Pack of 1, Grey)',
#        'Ambrane Unbreakable 60W / 3A Fast Charging 1.5m Braided Type C Cable for Smartphones, Tablets, Laptops & other Type C devices, PD Technology, 480Mbps Data Sync, Quick Charge 3.0 (RCT15A, Black)',
#        'Sounce Fast Phone Charging Cable & Data Sync USB Cable Compatible for iPhone 13, 12,11, X, 8, 7, 6, 5, iPad Air, Pro, Mini & iOS Devices',
#        ...,
#        'Bajaj Majesty RX10 2000 Watts Heat Convector Room Heater (White, ISI Approved)',
#        'Havells Ventil Air DSP 230mm Exhaust Fan (Pista Green)',
#        'Borosil Jumbo 1000-Watt Grill Sandwich Maker (Black)'],
#       dtype=object)

# %% [markdown]
# Kolom product_name berisi nama produk dalam bentuk deskripsi  lengkap yang mencakup tipe tipe produk. Seluruh tipe data sudah berbentuk teks dan secara format menunjukkan tidak adanya indikasi inkonsistensi dikarenakan tipe data sudah berupa huruf tanpa adanya perbedaan penulisan yang mencolok.

# %%
df['category'].unique()
# Out:
# array(['Computers&Accessories|Accessories&Peripherals|Cables&Accessories|Cables|USBCables',
#        'Computers&Accessories|NetworkingDevices|NetworkAdapters|WirelessUSBAdapters',
#        'Electronics|HomeTheater,TV&Video|Accessories|Cables|HDMICables',
#        'Electronics|HomeTheater,TV&Video|Televisions|SmartTelevisions',
#        'Electronics|HomeTheater,TV&Video|Accessories|RemoteControls',
#        'Electronics|HomeTheater,TV&Video|Televisions|StandardTelevisions',
#        'Electronics|HomeTheater,TV&Video|Accessories|TVMounts,Stands&Turntables|TVWall&CeilingMounts',
#        'Electronics|HomeTheater,TV&Video|Accessories|Cables|RCACables',
#        'Electronics|HomeAudio|Accessories|SpeakerAccessories|Mounts',
#        'Electronics|HomeTheater,TV&Video|Accessories|Cables|OpticalCables',
#        'Electronics|HomeTheater,TV&Video|Projectors',
#        'Electronics|HomeAudio|Accessories|Adapters',
# ...

# %% [markdown]
# Seluruh nilai pada kolom category memiliki pola penulisan yang konsisten dan tidak ditemukan perbedaan format, huruf besar/kecil yang tidak wajar, atau variasi penulisan yang merujuk pada kategori yang sama. Dengan demikian, tidak terdapat inkonsistensi nilai pada kolom category.

# %%
df['discounted_price'].unique()
# Out:
# array(['₹399', '₹199', '₹329', '₹154', '₹149', '₹176.63', '₹229', '₹499',
#        '₹299', '₹219', '₹350', '₹159', '₹349', '₹13,999', '₹249',
#        '₹13,490', '₹970', '₹279', '₹59', '₹11,499', '₹14,999', '₹179',
#        '₹389', '₹599', '₹99', '₹899', '₹32,999', '₹209', '₹19,999',
#        '₹999', '₹333', '₹507', '₹309', '₹1,199', '₹799', '₹6,999', '₹230',
#        '₹649', '₹15,999', '₹348', '₹32,990', '₹139', '₹263', '₹7,999',
#        '₹1,599', '₹26,999', '₹115', '₹10,901', '₹1,434', '₹7,299', '₹325',
#        '₹29,999', '₹27,999', '₹30,990', '₹269', '₹24,999', '₹18,990',
#        '₹290', '₹345', '₹1,099', '₹719', '₹849', '₹21,999', '₹449',
#        '₹37,999', '₹7,390', '₹273.10', '₹15,990', '₹210', '₹1,299',
#        '₹347', '₹228', '₹1,499', '₹8,499', '₹20,990', '₹9,999', '₹489',
#        '₹23,999', '₹689', '₹1,699', '₹655', '₹749', '₹195', '₹416',
#        '₹368', '₹29,990', '₹339', '₹15,490', '₹9,490', '₹637', '₹1,089',
# ...

# %% [markdown]
# Pada kolom discounted_price, seluruh data menggunakan simbol mata uang Indian Rupee di setiap awal nilai. Selain itu, terdapat penggunaan tanda koma sebagai pemisah ribuan serta beberapa nilai berbentuk desimal. Secara format, penulisan harga sudah konsisten karena diawali dengan simbol mata uang dan simbol diskon yang sama.
# Namun, karena adanya simbol mata uang dan tanda koma, kolom discounted_price terbaca sebagai tipe data object sehingga belum dapat diproses sebagai data numerik. Meskipun bertipe object, tidak ditemukan inkonsistensi dalam format penulisan harga pada kolom tersebut.

# %%
df['actual_price'].unique()
# Out:
# array(['₹1,099', '₹349', '₹1,899', '₹699', '₹399', '₹1,000', '₹499',
#        '₹299', '₹999', '₹339', '₹799', '₹700', '₹899', '₹24,999',
#        '₹21,990', '₹1,799', '₹22,900', '₹199', '₹19,990', '₹19,999',
#        '₹1,999', '₹750', '₹599', '₹666.66', '₹1,900', '₹45,999', '₹695',
#        '₹34,999', '₹1,599', '₹1,208', '₹475', '₹395', '₹2,199', '₹500',
#        '₹2,100', '₹12,999', '₹1,399', '₹21,999', '₹1,499', '₹47,900',
#        '₹845', '₹1,400', '₹14,990', '₹2,999', '₹42,999', '₹30,990',
#        '₹3,999', '₹249', '₹19,125', '₹1,299', '₹39,999', '₹40,990',
#        '₹52,900', '₹800', '₹31,999', '₹1,809', '₹29,999', '₹65,000',
#        '₹20,000', '₹23,990', '₹15,999', '₹44,990', '₹44,999', '₹1,700',
#        '₹595', '₹27,990', '₹1,200', '₹34,990', '₹1,500', '₹49,990',
#        '₹931', '₹2,399', '₹1,339', '₹20,900', '₹15,990', '₹1,600', '₹849',
#        '₹1,199', '₹22,990', '₹2,499', '₹47,990', '₹485', '₹18,990',
# ...

# %% [markdown]
# Sama halnya dengan kolom sebelumnya, actual_price juga seluruh data diawali dengan simbol mata uang Indian Rupee. Selain itu juga terdapat penggunaan tanda koma sebagai pemisah ribuan dan beberapa nilai  berbentuk desimal. Format penulisan harga terlihat konsisten karena seluruh nilai menggunakan simbol mata uang yang sama dan pola angka yang seragam sehingga tidak ditemukannya inkonsistensi value. Namun, karena adanya simbol mata uang dan tanda koma, kolom actual_price terbaca sebagai tipe data object sehingga belum dapat diproses sebagai data numerik.

# %%
df['discount_percentage'].unique()
# Out:
# array(['64%', '43%', '90%', '53%', '61%', '85%', '65%', '23%', '50%',
#        '33%', '55%', '63%', '69%', '60%', '13%', '44%', '38%', '39%',
#        '46%', '41%', '70%', '42%', '72%', '25%', '51%', '73%', '0%',
#        '80%', '28%', '67%', '58%', '35%', '45%', '62%', '54%', '27%',
#        '77%', '56%', '78%', '31%', '86%', '47%', '37%', '75%', '32%',
#        '68%', '66%', '22%', '57%', '17%', '52%', '88%', '20%', '59%',
#        '40%', '26%', '29%', '83%', '71%', '15%', '76%', '48%', '82%',
#        '36%', '89%', '87%', '24%', '34%', '11%', '91%', '7%', '19%',
#        '79%', '21%', '81%', '18%', '49%', '30%', '84%', '10%', '6%',
#        '14%', '74%', '4%', '5%', '16%', '8%', '2%', '94%', '12%', '3%',
#        '9%'], dtype=object)

# %% [markdown]
# Pada kolom discount_percentage, seluruh data ditulis menggunakan format tanda persen diakhir nilai. Format penulisan tersebut sudah terlihat konsisten dan tidak ditemukan variasi yang berbeda. Namun karena menggunakan simbol persen diakhir nilai, menyebabkan kesalahan dalam pembacaan tipe data yang mengakibatkan tipe data discount_percentage terbaca sebagai object, sehingga perlu dilakukan perbaikan pada dataset.

# %%
df['rating'].unique()
# Out:
# array(['4.2', '4.0', '3.9', '4.1', '4.3', '4.4', '4.5', '3.7', '3.3',
#        '3.6', '3.4', '3.8', '3.5', '4.6', '3.2', '5.0', '4.7', '3.0',
#        '2.8', '4', '3.1', '4.8', '2.3', '|', '2', '3', '2.6', '2.9'],
#       dtype=object)

# %% [markdown]
# Berdasarkan pengecekkan pada kolom rating, sebagian besar nilai berupa angka desimal. Namun, ditemukan satu nilai yang tidak sesuai format penulisan rating. Karena terdapat satu nilai yang tidak sesuai formatnya, maka pada kolom rating terdapat satu inconsistent value. Selain itu, karena adanya nilai yang berbeda, menyebabkan tipe data kolom rating menjadi object bukan integer atau float sehingga diperlukan perbaikan dalam penulisan data.

# %%
df['rating_count'].unique()
# Out:
# array(['24,269', '43,994', '7,928', ..., '468', '8,031', '6,987'],
#       dtype=object)

# %% [markdown]
# Kolom rating_count tidak termasuk inconsistent value karena seluruh nilai memiliki format yang konsisten berupa angka dengan pemisah ribuan menggunakan tanda koma. Tidak ditemukan karakter aneh atau format berbeda yang menyimpang dari pola tersebut. Tanda “...” yang terlihat pada output hanya merupakan pemotongan tampilan oleh pandas karena jumlah data yang banyak, sehingga bukan bagian dari isi data sebenarnya.

# %%
df['about_product'].unique()
# Out:
# array(["High Compatibility : Compatible With iPhone 12, 11, X/XsMax/Xr ,iPhone 8/8 Plus,iPhone 7/7 Plus,iPhone 6s/6s Plus,iPhone 6/6 Plus,iPhone 5/5s/5c/se,iPad Pro,iPad Air 1/2,iPad mini 1/2/3,iPod nano7,iPod touch and more apple devices.|Fast Charge&Data Sync : It can charge and sync simultaneously at a rapid speed, Compatible with any charging adaptor, multi-port charging station or power bank.|Durability : Durable nylon braided design with premium aluminum housing and toughened nylon fiber wound tightly around the cord lending it superior durability and adding a bit to its flexibility.|High Security Level : It is designed to fully protect your device from damaging excessive current.Copper core thick+Multilayer shielding, Anti-interference, Protective circuit equipment.|WARRANTY: 12 months warranty and friendly customer services, ensures the long-time enjoyment of your purchase. If you meet any question or problem, please don't hesitate to contact us.",
# ...

# %% [markdown]
# Kolom about_product berisi deskripsi atau spesifikasi produk dalam bentuk teks panjang yang dipisahkan menggunakan simbol “|” sebagai pembatas antar poin. Format penulisan terlihat konsisten karena mayoritas data menggunakan struktur deskripsi menggunakan huruf. Tidak ditemukan inkonsistensi nilai, karena perbedaan isi hanya berupa variasi informasi produk, bukan kesalahan format. Oleh karena itu, kolom ini sudah sesuai sebagai tipe data object.

# %%
df['user_id'].unique()
# Out:
# array(['AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBBSNLYT3ONILA,AHCTC6ULH4XB6YHDY6PCH2R772LQ,AGYHHIERNXKA6P5T7CZLXKVPT7IQ,AG4OGOFWXJZTQ2HKYIOCOY3KXF2Q,AENGU523SXMOS7JPDTW52PNNVWGQ,AEQJHCVTNINBS4FKTBGQRQTGTE5Q,AFC3FFC5PKFF5PMA52S3VCHOZ5FQ',
#        'AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBXNGXZJT525AQ,AHONIZU3ICIEHQIGQ6R2VFRSBXOQ,AFPHD2CRPDZMWMBL7WXRSVYWS5JA,AEZ346GX3HJ4O4XNRPHCNHXQURMQ,AEPSWFPNECKO34PUC7I56ITGXR6Q,AHWVEHR5DYLVFTO2KF3IZATFQSWQ,AH4QT33M55677I7ISQOAKEQWACYQ',
#        'AGU3BBQ2V2DDAMOAKGFAWDDQ6QHA,AESFLDV2PT363T2AQLWQOWZ4N3OA,AHTPQRIMGUD4BYR5YIHBH3CCGEFQ,AEUVWXYP5LT7PZLLZENEO2NODPBQ,AHC7MPW55DOO6WNCOQVA2VHOD26A,AFDI6FRPFBTNBG7BAEB7JDJSMKDQ,AFQKCEEEKXCOHTDG4WUN3XPPHJQQ,AHKUUFNMBZIDLSSPA4FEHIO2EC7Q',
#        ...,
#        'AGVPWCMAHYQWJOQKMUJN4DW3KM5Q,AF4Q3E66MY4SR7YQZSWBBRU5XQKQ,AEM2ZDSQE4QZIGTCTE4HSNZOS7DQ,AEHMIAQFYXW3CY6Z37ABRXSOJRPA,AHJCYSNMFLZM7CA4FGDPU7A4UHYQ,AEQTWNQ6GKTOSJO3ZEPHRTH56VCA,AHIHPBLP6PPV66Y3AWOSYFBVZPFA,AGHBKUHIWVOPUQYFRA6PXIIC6R5Q',
# ...

# %% [markdown]
# Kolom user_id berisi kode unik pengguna dalam bentuk kombinasi huruf dan angka. Format penulisan terlihat konsisten tanpa adanya karakter aneh atau pola yang berbeda. Tidak ditemukan inkonsistensi nilai karena seluruh data mengikuti struktur yang seragam sebagai identifier pengguna. Oleh karena itu, kolom ini sudah sesuai bertipe object dan tidak memerlukan proses standarisasi lebih lanjut.

# %%
df['user_name'].unique()
# Out:
# array(['Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jaspreet singh,Khaja moin,Anand,S.ARUMUGAM',
#        'ArdKn,Nirbhay kumar,Sagar Viswanathan,Asp,Placeholder,BharanI,sonia,Niam',
#        'Kunal,Himanshu,viswanath,sai niharka,saqib malik,Aashiq,Ramu Challa,Sanjay gupta',
#        ...,
#        'Nehal Desai,Danish Parwez,Amazon Customer,Amazon Customer,Pankaj Kumar Singh,Pattabhi udaya kumar,Sandip Bhargava,BATTU SURESHKUMAR',
#        'Shubham Dubey,E.GURUBARAN,Mayank S.,eusuf khan,ASHISHGAJBE,hirabhai thakarda,khageswar,A.Ramu',
#        'Rajib,Ajay B,Vikas Kahol,PARDEEP,Anindya Pramanik,Vikas Singh,Harshada Pimple,Saw a.'],
#       dtype=object)

# %% [markdown]
# Kolom user_name berisi nama pengguna dalam bentuk teks yang dipisahkan dengan tanda koma dalam satu sel. Format penulisan terlihat konsisten karena seluruh data berupa kumpulan nama tanpa karakter aneh atau simbol yang tidak sesuai. Tidak ditemukan inkonsistensi nilai, karena variasi yang ada hanya berupa perbedaan nama pengguna, bukan kesalahan format. Oleh karena itu, kolom ini sudah sesuai bertipe object dan tidak memerlukan standarisasi, kecuali jika ingin dipisahkan menjadi beberapa nama secara terstruktur.

# %%
df['review_id'].unique()
# Out:
# array(['R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1KD19VHEDV0OR,R3C02RMYQMK6FC,R39GQRVBUZBWGY,R2K9EDOE15QIRJ,R3OI7YT648TL8I',
#        'RGIQEG07R9HS2,R1SMWZQ86XIN8U,R2J3Y1WL29GWDE,RYGGS0M09S3KY,R17KQRUTAN5DKS,R3AAQGS6HP2QUK,R1HDNOG6TO2CCA,R3PHKXYA5AFEOU',
#        'R3J3EQQ9TZI5ZJ,R3E7WBGK7ID0KV,RWU79XKQ6I1QF,R25X4TBMPY91LX,R27OK7G99VK0TR,R207CYDCHJJTCJ,R3PCU8XMU173BT,R1IMONDOWRNU5V',
#        ...,
#        'R1TLRJVW4STY5I,R2O455KRN493R1,R3Q5MVGBRIAS2G,RDUWK5R7MYO0F,R2PLXU82PLNOS,R3OGEQWZH4DYFA,R5I0WH8YY7K9V,R1MC4M4R6ZDUBE',
#        'R39Q2Y79MM9SWK,R3079BG1NIH6MB,R29A31ZELTZNJM,RQ7XAO5UTJQZT,R223OFAZGIK4X7,R27WMZV25K3TN1,R302QB4GVL3F8T,RBZRSE5J6HCF3',
#        'R20RBRZ0WEUJT9,ROKIFK9R2ISSE,R30EEG2FNJSN5I,R2ZC03S4QXOW4Y,R186H8YW34BQD5,R10NC3D321N59G,REKF75G4SOAOX,R2G0ZT4JQX322I'],
#       dtype=object)

# %% [markdown]
# Kolom review_id berisi kode unik ulasan dalam bentuk kombinasi huruf dan angka. Format penulisan terlihat konsisten tanpa adanya karakter aneh atau pola yang berbeda. Seluruh nilai mengikuti struktur yang seragam, sehingga tidak ditemukan inconsistent value pada kolom tersebut. Oleh karena itu, kolom ini sudah sesuai bertipe object dan tidak memerlukan standarisasi lebih lanjut.

# %%
df['review_title'].unique()
# Out:
# array(['Satisfied,Charging is really fast,Value for money,Product review,Good quality,Good product,Good Product,As of now seems good',
#        'A Good Braided Cable for Your Type C Device,Good quality product from ambrane,Super cable,As,Good quality,Good product,its good,Good quality for the price but one issue with my unit',
#        "Good speed for earlier versions,Good Product,Working good,Good for the price,Good,Worth for money,Working nice,it's a really nice product",
#        ...,
#        'very good,Work but front melt after 2 month,Good one,It is durable,Review.,DEFECTIVE PRODUCT,Nice product,Nice product',
#        'Fan Speed is slow,Good quality,Good product,good,Old is gold.,Good product,Nice product,Super 💕',
#        'Works perfect,Ok good product,Nice Product. Recommend it. But cleaning its exterior is cumbersome.,Excellent product✌,A good product for household use,मुझे बिल्कुल भी मजा नहीं आया और वापस कर दिया।,Best product,Good'],
#       dtype=object)

# %% [markdown]
# Kolom review_title berisi judul ulasan dalam bentuk teks yang dipisahkan dengan tanda koma dalam satu sel. Secara umum format penulisan terlihat konsisten karena seluruh data berupa teks tanpa pola yang yang berbeda. Perbedaan isi hanya berupa variasi bahasa pengguna,sehingga tidak termasuk inconsistent value. Namun, terdapat variasi penggunaan huruf besar/kecil dan tanda baca yang berbeda, tetapi hal tersebut masih wajar dalam data ulasan pengguna dan tidak dianggap sebagai kesalahan format.

# %%
df['review_content'].unique()
# Out:
# array(['Looks durable Charging is fine tooNo complains,Charging is really fast, good product.,Till now satisfied with the quality.,This is a good product . The charging speed is slower than the original iPhone cable,Good quality, would recommend,https://m.media-amazon.com/images/W/WEBP_402378-T1/images/I/81---F1ZgHL._SY88.jpg,Product had worked well till date and was having no issue.Cable is also sturdy enough...Have asked for replacement and company is doing the same...,Value for money',
# ...

# %% [markdown]
# Kolom review_content berisi isi ulasan pengguna dalam bentuk teks panjang. Secara umum format penulisan terlihat konsisten karena seluruh data berupa teks opini pengguna. Terdapat variasi bahasa (Bahasa Inggris dan Bahasa India), emoji, serta beberapa tautan gambar (URL), namun hal tersebut tidak termasuk inconsistent value karena masih merupakan bagian wajar dari konten ulasan. Tidak ditemukan pola format yang menyimpang atau karakter acak yang tidak relevan. Oleh karena itu, kolom ini sudah sesuai bertipe object.

# %%
df['img_link'].unique()
# Out:
# array(['https://m.media-amazon.com/images/W/WEBP_402378-T1/images/I/51UsScvHQNL._SX300_SY300_QL70_FMwebp_.jpg',
#        'https://m.media-amazon.com/images/W/WEBP_402378-T2/images/I/31zOsqQOAOL._SY445_SX342_QL70_FMwebp_.jpg',
#        'https://m.media-amazon.com/images/W/WEBP_402378-T1/images/I/31IvNJZnmdL._SY445_SX342_QL70_FMwebp_.jpg',
#        ...,
#        'https://m.media-amazon.com/images/W/WEBP_402378-T1/images/I/41qmt2a159L._SX300_SY300_QL70_FMwebp_.jpg',
#        'https://m.media-amazon.com/images/W/WEBP_402378-T1/images/I/51pNg1Zy4+L._SX300_SY300_.jpg',
#        'https://m.media-amazon.com/images/W/WEBP_402378-T1/images/I/51J2Wk-+c+L._SY300_SX300_.jpg'],
#       dtype=object)

# %% [markdown]
# Kolom image_link berisi tautan URL gambar produk yang seluruhnya diawali dengan format “https://”. Struktur link terlihat konsisten dan berasal dari domain yang sama, yaitu media Amazon. Tidak ditemukan karakter aneh atau format yang menyimpang, sehingga tidak terdapat inconsistent value pada kolom ini. Kolom ini memang sesuai bertipe object karena berisi teks berupa alamat URL.

# %%
df['product_link'].unique()
# Out:
# array(['https://www.amazon.in/Wayona-Braided-WN3LG1-Syncing-Charging/dp/B07JW9H4J1/ref=sr_1_1?qid=1672909124&s=electronics&sr=1-1',
#        'https://www.amazon.in/Ambrane-Unbreakable-Charging-Braided-Cable/dp/B098NS6PVG/ref=sr_1_2?qid=1672909124&s=electronics&sr=1-2',
#        'https://www.amazon.in/Sounce-iPhone-Charging-Compatible-Devices/dp/B096MSW6CT/ref=sr_1_3?qid=1672909124&s=electronics&sr=1-3',
#        ...,
#        'https://www.amazon.in/Bajaj-RX-10-2000-Watt-Convector/dp/B009P2LIL4/ref=sr_1_504?qid=1672923617&s=kitchen&sr=1-504',
#        'https://www.amazon.in/Havells-Ventilair-230mm-Exhaust-Grey/dp/B00J5DYCCA/ref=sr_1_505?qid=1672923617&s=kitchen&sr=1-505',
#        'https://www.amazon.in/Borosil-Jumbo-1000-Watt-Grill-Sandwich/dp/B01486F4G6/ref=sr_1_506?qid=1672923617&s=kitchen&sr=1-506'],
#       dtype=object)

# %% [markdown]
# Kolom product_link berisi tautan URL produk yang seluruhnya diawali dengan format “https://www.amazon.in/”
# . Struktur link terlihat konsisten dan berasal dari domain yang sama, yaitu Amazon India. Tidak ditemukan format yang menyimpang atau karakter yang tidak sesuai, sehingga tidak terdapat inconsistent value pada kolom ini. Kolom ini sudah tepat bertipe object karena berisi teks berupa alamat URL produk.

# %% [markdown]
# #**Missing Values**

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio in %'])
# Out:
#                      Null Ratio in %
# product_id                  0.000000
# product_name                0.000000
# category                    0.000000
# discounted_price            0.000000
# actual_price                0.000000
# discount_percentage         0.000000
# rating                      0.000000
# rating_count                0.136519
# about_product               0.000000
# user_id                     0.000000
# user_name                   0.000000
# review_id                   0.000000
# review_title                0.000000
# review_content              0.000000
# img_link                    0.000000
# product_link                0.000000

# %% [markdown]
# Dari hasil pengecekan missing values terlihat bahwa seluruh kolom tidak memiliki data yang hilang, kecuali kolom rating_count yang memiliki 2 data kosong. Jumlah missing tersebut sangat sedikit dibandingkan total data yang ada, sehingga tidak memberikan pengaruh signifikan terhadap proses analisis. Secara keseluruhan, dataset dapat dikatakan memiliki kualitas yang baik karena hampir seluruh data lengkap.

# %% [markdown]
# #**Duplicated Values**

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [product_id, product_name, category, discounted_price, actual_price, discount_percentage, rating, rating_count, about_product, user_id, user_name, review_id, review_title, review_content, img_link, product_link]
# Index: []

# %% [markdown]
# Berdasarkan hasil pemeriksaan duplicated values, tidak ditemukan data yang terduplikasi dalam dataset. Hal ini menunjukkan bahwa data bersifat unik dan tidak terdapat pengulangan data yang dapat mempengaruhi hasil analisis. Dengan demikian, dataset dapat dikatakan bersih dari duplikasi.

# %% [markdown]
# #**Outliers**

# %%
results = []
cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
    q1 = df[col].quantile(0.25)
    q3 = df[col].quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5*iqr
    upper_bound = q3 + 1.5*iqr
    outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
    percent_outliers = (len(outliers)/len(df))*100
    results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

pd.DataFrame(results)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# Berdasarkan hasil pengecekan, ditemukan beberapa data dengan simbol pada nilai yang menyebabkan sistem tidak dapat membaca data tersebut. Namun, kolom-kolom tersebut akan serga diperbaiki agar outliers dapat membaca sistem dan menampilkan output.

# %% [markdown]
# #**Exploratory Data Analysis (EDA)**

# %% [markdown]
# ##**Comparison**

# %%
df['main_category'] = df['category'].str.split('|').str[0]

main_cat = df['main_category'].value_counts()

plt.figure(figsize=(10,6))
sns.barplot(x=main_cat.values, y=main_cat.index)
plt.title('Jumlah Produk per Main Category')
plt.show()

# %% [markdown]
# Berdasarkan grafik jumlah produk per main category, terlihat bahwa kategori Electronics memiliki jumlah produk paling banyak dibandingkan kategori lainnya. Disusul oleh Computers & Accessories dan Home & Kitchen yang juga memiliki jumlah produk cukup tinggi. Sementara itu, kategori seperti Office Products, Musical Instruments, Toys & Games, Car & Motorbike, dan Health & Personal Care memiliki jumlah produk yang jauh lebih sedikit.
# Hal ini menunjukkan bahwa dataset didominasi oleh produk-produk elektronik dan perlengkapan teknologi, sehingga analisis yang dilakukan kemungkinan besar akan lebih merepresentasikan karakteristik pasar produk elektronik dibandingkan kategori lainnya.

# %% [markdown]
# ##**Compoition**

# %%
df['rating_count'] = df['rating_count'].str.replace(',', '', regex=True)
df['rating_count'] = pd.to_numeric(df['rating_count'], errors='coerce')
df['rating_count'] = df['rating_count'].fillna(0).astype(int)

sales_by_category = df.groupby('main_category')['rating_count'].sum().sort_values(ascending=False)

top5 = sales_by_category.head(5)

plt.figure(figsize=(8,8))
plt.pie(top5.values, labels=top5.index, autopct='%1.1f%%')
plt.title('Komposisi Total Rating Count per Main Category (Top 5)')
plt.show()

# %% [markdown]
# Berdasarkan pie chart komposisi total rating count per main category, terlihat bahwa kategori Electronics mendominasi dengan kontribusi sekitar 59% dari total rating. Disusul oleh Computers & Accessories sebesar kurang lebih 28,9%, dan Home & Kitchen sekitar 11,2%. Sementara kategori lainnya seperti Office Products dan Musical Instruments hanya memberikan kontribusi yang sangat kecil.
# Hal ini menunjukkan bahwa sebagian besar interaksi dan minat pelanggan terpusat pada produk elektronik dan perlengkapan komputer. Distribusi ini juga menandakan bahwa pasar dalam dataset sangat terkonsentrasi pada kategori teknologi dibandingkan kategori lainnya.

# %% [markdown]
# ##**Distribution**

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['rating'], bins=10, kde=True)
plt.title('Distribusi Rating Produk')
plt.xlabel('Rating')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# Berdasarkan histogram distribusi rating, terlihat bahwa sebagian besar produk memiliki rating di rentang 3.8 hingga 4.5, dengan puncak distribusi berada di sekitar rating 4.0 sampai 4.3. Hal ini menunjukkan bahwa mayoritas produk dalam dataset mendapatkan penilaian yang cukup tinggi dari pengguna.
# Sementara itu, jumlah produk dengan rating sangat rendah di rating 3, maupun sangat tinggi di rating 5 relatif lebih sedikit. Distribusi ini cenderung miring ke kiri, yang berarti lebih banyak produk memiliki rating tinggi dibandingkan rating rendah.
# Secara umum, dapat disimpulkan bahwa kualitas produk dalam dataset ini tergolong baik karena didominasi oleh rating di atas 4.

# %% [markdown]
# ##**Relationship**

# %%
df['actual_price'] = df['actual_price'].str.replace('₹', '', regex=False).str.replace(',', '', regex=False).astype(float)
df['discounted_price'] = df['discounted_price'].str.replace('₹', '', regex=False).str.replace(',', '', regex=False).astype(float)
df['discount_percentage'] = df['discount_percentage'].str.replace('%', '', regex=False).astype(float)
df['rating'] = df['rating'].replace({'|': np.nan}).astype(float)

plt.figure(figsize=(8, 6))
sns.heatmap(df[['actual_price', 'rating_count']].corr(),
            annot=True,
            cmap='viridis',
            fmt='.2f')
plt.title('Korelasi antara Harga dan Jumlah Rating')
plt.show()

# %% [markdown]
# Berdasarkan heatmap korelasi antara actual_price dan rating_count, diperoleh nilai korelasi sebesar -0.04. Nilai ini sangat mendekati nol, sehingga menunjukkan bahwa hubungan antara harga produk dan jumlah rating sangat lemah atau hampir tidak ada hubungan linear.
# Artinya, produk dengan harga lebih mahal tidak selalu memiliki jumlah rating yang lebih banyak, dan produk dengan harga lebih murah juga tidak selalu memiliki jumlah rating yang lebih sedikit. Dengan kata lain, tingkat popularitas (diukur dari jumlah rating) tidak dipengaruhi secara signifikan oleh harga produk.

# %% [markdown]
# # **Data Preparation**

# %% [markdown]
# ## **Tipe Data**

# %%
df.dtypes
# Out:
# product_id              object
# product_name            object
# category                object
# discounted_price       float64
# actual_price           float64
# discount_percentage    float64
# rating                 float64
# rating_count             int64
# about_product           object
# user_id                 object
# user_name               object
# review_id               object
# review_title            object
# review_content          object
# img_link                object
# product_link            object
# main_category           object
# dtype: object

# %% [markdown]
# Berdasarkan hasil pengecekan tipe data, seluruh kolom telah memiliki tipe data yang sesuai dengan isi datanya, sehingga tidak diperlukan perubahan tipe data pada tahap data preparation.

# %% [markdown]
# ## **Inconsistent Values**

# %% [markdown]
# Melalui pengecekkan sebelumnya tidak ditemukan adanya inconsistent values dari beberapa kolom. Sehingga, tidak diperlukan perbaikan format pada kolom.

# %% [markdown]
# ## **Missing Values**

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio in %'])
# Out:
#                      Null Ratio in %
# product_id                  0.000000
# product_name                0.000000
# category                    0.000000
# discounted_price            0.000000
# actual_price                0.000000
# discount_percentage         0.000000
# rating                      0.068259
# rating_count                0.000000
# about_product               0.000000
# user_id                     0.000000
# user_name                   0.000000
# review_id                   0.000000
# review_title                0.000000
# review_content              0.000000
# img_link                    0.000000
# product_link                0.000000
# main_category               0.000000

# %% [markdown]
# Berdasarkan hasil pengecekan, hanya kolom eating yang memiliki nilai kosong sebesar 6.8%. Karena jumlahnya relatif kecil serta kolom ini perlu ditindak lanjuti, maka kolom missing values ini bisa menggunakan metode nilai median agar data kembali stabil.

# %%
df['rating'] = df['rating'].fillna(df['rating'].dropna().median())

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio in %'])
# Out:
#                      Null Ratio in %
# product_id                       0.0
# product_name                     0.0
# category                         0.0
# discounted_price                 0.0
# actual_price                     0.0
# discount_percentage              0.0
# rating                           0.0
# rating_count                     0.0
# about_product                    0.0
# user_id                          0.0
# user_name                        0.0
# review_id                        0.0
# review_title                     0.0
# review_content                   0.0
# img_link                         0.0
# product_link                     0.0
# main_category                    0.0

# %% [markdown]
# Setelah dilakukannya perbaikan pada kolom rating menggunakan metode nilai median, terlihat bahwa nilai kolom rating sudah 0.0 mengikuti kolom lainnya, sehingga setelah proses pembersihan data tidak terdapat lagi missing value pada seluruh kolom.

# %% [markdown]
# ## **Duplicated Values**

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [product_id, product_name, category, discounted_price, actual_price, discount_percentage, rating, rating_count, about_product, user_id, user_name, review_id, review_title, review_content, img_link, product_link, main_category]
# Index: []

# %% [markdown]
# Tidak ditemukan juga indikasi duplicated values melalui pengecekan sebelumnya dan pengecekan baru baru ini, sehingga tidak diperlukan adanya penghapusan nilai yang terduplikat.

# %% [markdown]
# ## **Outliers**

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom                Persentase Outliers
# discounted_price               14.812287
# actual_price                   14.539249
# discount_percentage             0.000000
# rating                          5.051195
# rating_count                    9.624573

# %% [markdown]
# Ditemukan beberapa nilai yang sangat tinggi atau rendah dibandingkan data nilai lainnya, terutama pada kolom actual_price, rating, dan rating_count. Namun nilai tersebut masih masuk akal dalam konteks e-commerce, seperti produk premium dengan harga tinggi atau produk populer dengan banyak ulasan. Oleh karena itu, data tidak dihapus agar informasi penting tetap terjaga.

# %%
columns_to_impute = ["discounted_price", "actual_price", "discount_percentage", "rating", "rating_count" ]

for col in columns_to_impute:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Menggunakan .loc[] agar tidak muncul SettingWithCopyWarning
    df.loc[:, col] = df[col].clip(lower=lower_bound, upper=upper_bound)

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom                Persentase Outliers
# discounted_price                     0.0
# actual_price                         0.0
# discount_percentage                  0.0
# rating                               0.0
# rating_count                         0.0

# %% [markdown]
# # **Visualisasi**

# %% [markdown]
# ## **Bar Chart**

# %%
kategori = df['main_category'].value_counts().head(5).sort_values(ascending=False)
plt.figure(figsize=(10, 6))
plt.bar(kategori.index, kategori.values, color='skyblue')
plt.xlabel('Kategori Barang')
plt.ylabel('Total Penjualan')
plt.title('Total Jumlah Penjualan berdasarkan Kategori')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Insight Bar Chart**

# %% [markdown]
# Kategori Electronics memiliki jumlah penjualan tertinggi dibandingkan kategori lainnya. Sementara itu, Musical Instruments memiliki penjualan paling rendah. Hal ini menunjukkan bahwa produk elektronik lebih diminati oleh pelanggan, sehingga perusahaan dapat memfokuskan strategi penjualan dan promosi pada kategori tersebut.

# %% [markdown]
# ### **Action Bar Chart**

# %% [markdown]
# Amzon dapat memfokuskan strategi pemasaran dan meningkatkan ketersediaan stok pada kategori produk dengan jumlah penjualan tertinggi. Selain itu, kategori dengan penjualan rendah dapat dievaluasi kembali melalui promosi tambahan atau strategi pemasaran yang lebih menarik agar dapat meningkatkan penjualan.

# %% [markdown]
# ## **Pie Chart**

# %%
df['main_category'].value_counts().head(5)
plt.figure(figsize=(10, 6))
plt.pie(df['main_category'].value_counts(), labels=df['main_category'].value_counts().index, autopct='%1.1f%%', colors=['lightcoral', 'lightblue', 'lightgreen', 'gold']) # colors (warna)
plt.title('Top 5 Penjualan')
plt.show()

# %% [markdown]
# ### **Insight Pie Chart**

# %% [markdown]
# Distribusi kategori produk menunjukkan bahwa Electronics merupakan kategori dengan kontribusi terbesar, diikuti oleh Computers & Accessories dan Home & Kitchen. Ketiga kategori tersebut mendominasi sebagian besar penjualan, sementara kategori lainnya hanya memberikan kontribusi yang kecil terhadap total keseluruhan sampai-sampai tidak terbaca dengan jelas.

# %% [markdown]
# ### **Action Pie Chart**

# %% [markdown]
# Kategori produk yang memiliki persentase terbesar dapat dijadikan prioritas dalam strategi penjualan karena memberikan kontribusi paling besar terhadap keseluruhan produk atau penjualan. Maka dari itu, Amazon juga dapat meningkatkan promosi pada kategori lain yang kontribusinya lebih kecil agar distribusi penjualan menjadi lebih seimbang.

# %% [markdown]
# ## **Line Chart**

# %% [markdown]
# Line chart tidak digunakan karena dataset tidak memiliki kolom yang menunjukkan urutan waktu atau jarak data yang kontinu seperti tanggal atau bulan, sehingga tidak dapat menampilkan tren perubahan data.

# %% [markdown]
# ## **Histogram**

# %%
plt.figure(figsize=(8, 5))
plt.hist(df['discount_percentage'], bins=20, color='blue', edgecolor='black')
plt.title('Distribusi Persentase Diskon Produk')
plt.xlabel('Persentase Diskon Produk')
plt.ylabel('Jumlah Produk')
plt.show()

# %% [markdown]
# ### **Insight Histogram**

# %% [markdown]
# Sebagian besar produk memiliki persentase diskon pada rentang menengah sekitar 40% sampai 60%, yang terlihat dari tingginya frekuensi pada bagian tengah histogram. Hal ini menunjukkan bahwa banyak penjual memberikan diskon pada kisaran tersebut untuk menarik minat pembeli. Sementara itu, produk dengan diskon sangat rendah atau sangat tinggi jumlahnya lebih sedikit, sehingga tidak terlalu mendominasi dalam dataset.

# %% [markdown]
# ### **Action Histogram**

# %% [markdown]
# Dengan ini, Amazon dapat mempertimbangkan penggunaan strategi diskon pada rentang yang paling sering muncul dalam distribusi data, karena kemungkinan besar rentang diskon tersebut lebih efektif dalam menarik minat pembeli. Selain itu, Amazon dapat mengevaluasi rentang diskon yang jarang digunakan untuk melihat apakah strategi tersebut kurang efektif atau jarang diterapkan.

# %% [markdown]
# ## **BoxPlot**

# %%
harga_asli = df['actual_price'].value_counts().head(5).index
rating = df[df['actual_price'].isin(harga_asli)]

plt.figure(figsize=(12, 7))
rating.boxplot(column='rating', by='actual_price', ax=plt.gca(), grid=False, patch_artist=True, medianprops=dict(color='red'))
plt.title('Distribusi Rating Produk Berdasarkan Rentang Harga', fontsize=16)
plt.xlabel('Harga Produk', fontsize=12)
plt.ylabel('Rating Produk', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.suptitle('')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Insight Box Plot**

# %% [markdown]
# Sebagian besar produk pada berbagai rentang harga memiliki rating yang cukup tinggi. Hal ini menunjukkan bahwa produk dengan harga rendah maupun tinggi sama-sama mendapatkan penilaian yang baik dari pengguna. Beberapa titik di luar kotak menunjukkan outliers, yaitu produk dengan rating yang jauh berbeda dari sebagian besar produk.

# %% [markdown]
# ### **Action Box Plot**

# %% [markdown]
# Penjual dapat mempertahankan kualitas produk pada setiap rentang harga agar rating produk tetap stabil dan tinggi. Selain itu, produk yang memiliki rating rendah dapat dianalisis lebih lanjut untuk mengetahui penyebabnya, sehingga penjual dapat melakukan perbaikan pada kualitas produk atau layanan.

# %% [markdown]
# ## **ScatterPlot**

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['actual_price'], df['rating'], alpha=0.7, color='teal')
plt.title('Hubungan Harga Produk dengan Rating Produk', fontsize=16)
plt.xlabel('Harga Asli', fontsize=12)
plt.ylabel('Rating', fontsize=12)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Insight ScatterPlot**

# %% [markdown]
# Grafik scatterplot menunjukkan bahwa sebagian besar produk memiliki rating yang cukup tinggi, meskipun harga produk berada pada rentang yang berbeda-beda. Titik-titik pada grafik tersebar di berbagai tingkat harga, namun mayoritas tetap berada pada nilai rating yang relatif tinggi. Hal ini menunjukkan bahwa harga produk tidak selalu berpengaruh langsung terhadap tinggi rendahnya rating, karena baik produk dengan harga rendah maupun tinggi dapat memperoleh penilaian yang baik dari pengguna.

# %% [markdown]
# ### **Action ScatterPlot**

# %% [markdown]
# Penjual dapat terus meningkatkan kualitas produk dan pelayanan kepada pelanggan karena rating yang baik dapat meningkatkan kepercayaan pembeli. Selain itu, meskipun harga produk bervariasi, menjaga kualitas tetap tinggi dapat membantu mempertahankan rating yang baik dan meningkatkan potensi penjualan.

# %% [markdown]
# ## **Heatmap**

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(data=df[['actual_price', 'discount_percentage', 'rating_count']].corr(),
            annot=True,
            cmap='viridis',
            fmt='.2f')
plt.title('Korelasi antara Harga Produk, Persentase Diskon, dan Jumlah Ulasan')
plt.show()

# %% [markdown]
# ### **Insight Heatmap**

# %% [markdown]
# Heatmap menunjukkan bahwa hubungan antara harga produk, persentase diskon, dan jumlah ulasan relatif lemah, karena nilai korelasi antar variabel mendekati 0. Hal ini menunjukkan bahwa perubahan pada satu variabel tidak terlalu mempengaruhi variabel lainnya. Misalnya, harga produk tidak memiliki hubungan yang kuat dengan jumlah ulasan maupun persentase diskon pada dataset ini.

# %% [markdown]
# ### **Action Heatmap**

# %% [markdown]
# Perusahaan Amazon dapat melakukan analisis lebih lanjut terhadap variabel lain untuk menemukan faktor yang lebih mempengaruhi performa produk. Dengan memahami hubungan antar variabel secara lebih mendalam, perusahaan dapat menentukan strategi penjualan atau pemasaran yang lebih efektif di masa depan.
